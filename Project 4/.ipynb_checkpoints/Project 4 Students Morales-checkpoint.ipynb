# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# **Enter your Name:**_Jorge A. Morales Alfaro
# *Semester:* Fall 2023

# %% [raw]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
#pip install --upgrade  threadpoolctl
# Out:
# Requirement already satisfied: threadpoolctl in /Users/jorgeantoniomorales/opt/anaconda3/lib/python3.9/site-packages (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split
# Out:
# 2023-12-15 11:00:57.163280: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explained by each component. *Hint*: look at the attributes associated with your model.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %%
# We will make a PCA without limit, creating all the Principal components,
#then I will use a Scree plot and a bar plot to determine how many would be ideal
#--------------------------------------------------
np.random.seed(555)
# fit PCA
# ----------
pca_all = PCA() 
principalComponents_health = pca_all.fit_transform(nhanes_scaled)


# create scree plot from PCA fit
# ----------
PC_values = np.arange(pca_all.n_components_) + 1
plt.plot(PC_values, pca_all.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %% [markdown]
# It seems like after the 5 or 6th component curve starts to have very diminishing improvements.
# Still, There is some variance to recover at least until the 20-25th component.
# Which is not too bad, as we are coming from a 250 features dataset.

# %% [markdown]
# ### Barplot of Components

# %%
## I will then reduce the number of components to 20 and do a barplot to further analyze if I shoudl decrease the size


pca20 = PCA(n_components=20)
principalComponents_health20 = pca20.fit_transform(nhanes_scaled)

# %%
## Your Answer Here
variance_df = pd.DataFrame({'Principal Component': [f'PC{i+1}' for i in range(len(pca20.explained_variance_ratio_))],
                            'Variance Explained': pca20.explained_variance_ratio_})

# %%
# convert into a dataframe
# ----------

num_components = principalComponents_health20.shape[1]  # Number of principal components
columns = [f'principal component {i+1}' for i in range(num_components)]

pca_df = pd.DataFrame(data = principalComponents_health20, columns = columns)

# %%
pca_df.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               9.527811              -0.816224              -1.867090
# 1              -5.838339              -3.692573               3.805751
# 2              -0.719454              -2.573200               0.907903
# 3               3.533627              -2.576982              -3.249123
# 4              -6.872094              -4.194241               0.886832
#
#    principal component 4  principal component 5  principal component 6  \
# 0              -2.109892              -3.929294              -0.185683
# 1              -1.029616               0.394502               1.591797
# 2              -4.755835              -1.798878               0.863717
# 3              -0.405349               3.999210               1.443931
# 4              -0.848957              -0.524810               0.072990
#
#    principal component 7  principal component 8  principal component 9  \
# 0              -3.844800              -2.934948               1.515702
# 1               2.712994              -0.739719               0.385884
# 2              -1.024231               0.632360               0.540469
# 3              -1.181528               0.328007              -4.145221
# 4               0.844501               0.985883               0.556338
#
#    principal component 10  principal component 11  principal component 12  \
# 0                0.683973                0.120778                2.232560
# 1               -2.405193               -0.455442                1.095680
# 2                0.447583                0.168263               -1.317741
# 3               -1.245504               -0.783603                2.068753
# 4               -0.044216               -0.501676               -0.986643
#
#    principal component 13  principal component 14  principal component 15  \
# 0                0.284649               -0.654383                0.412075
# 1                0.468465                2.419563                0.503833
# 2                1.705656               -0.271960                0.458442
# 3               -2.346114                2.816273               -1.132660
# 4               -0.573329               -1.840725               -0.270546
#
#    principal component 16  principal component 17  principal component 18  \
# 0               -0.640991                0.352945                0.479144
# 1               -1.361836                0.590741               -0.650669
# 2               -0.765012               -0.002881               -0.523914
# 3               -1.283340                1.144368                0.614260
# 4               -0.088507               -0.688705               -0.234532
#
#    principal component 19  principal component 20
# 0               -0.502138                2.294842
# 1               -1.490594                1.899403
# 2                0.375148                3.291438
# 3                0.107755               -1.096708
# 4                2.173843                3.039866

# %%
sns.barplot(x='Principal Component', y='Variance Explained', data=variance_df, palette='viridis')
plt.title('Variance Explained by Principal Components')
plt.show()

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %% [markdown]
# After the graphical analysis, I am inclined to keep 5 to 10 components. I think for simplicty 5 would be ideal, but the accumulated variance does not seem to be a lot, so I am afrad I would loose valuable information. I'll keep 10 as that still makes my model clear to understand and interpret and preservees enough information.

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
pca_df['HSD010_binary'] = hsd010
pca_df['HSD010_binary'] = pca_df['HSD010_binary'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor'])

# %%
pca_df.head(100)
# Out:
#     principal component 1  principal component 2  principal component 3  \
# 0                9.527811              -0.816224              -1.867090
# 1               -5.838339              -3.692573               3.805751
# 2               -0.719454              -2.573200               0.907903
# 3                3.533627              -2.576982              -3.249123
# 4               -6.872094              -4.194241               0.886832
# ..                    ...                    ...                    ...
# 95               5.368887              -1.246562               1.794866
# 96              -3.800793              -1.153132              -0.192103
# 97              -3.187486              -1.724905               7.382479
# 98              -9.483802              12.310936              -2.126295
# 99               9.761894               0.834637              -4.773605
#
#     principal component 4  principal component 5  principal component 6  \
# 0               -2.109892              -3.929294              -0.185683
# 1               -1.029616               0.394502               1.591797
# 2               -4.755835              -1.798878               0.863717
# 3               -0.405349               3.999210               1.443931
# 4               -0.848957              -0.524810               0.072990
# ..                    ...                    ...                    ...
# 95              -2.356273               4.306454               4.120396
# 96              -0.666487               0.671990              -0.960983
# 97              -1.526182              -0.049840               1.923867
# 98              -2.140628              -1.573639               3.667399
# 99               2.071676               4.069677              -3.518482
#
#     principal component 7  principal component 8  principal component 9  \
# 0               -3.844800              -2.934948               1.515702
# 1                2.712994              -0.739719               0.385884
# 2               -1.024231               0.632360               0.540469
# 3               -1.181528               0.328007              -4.145221
# 4                0.844501               0.985883               0.556338
# ..                    ...                    ...                    ...
# 95              -1.502574               2.401699               0.048416
# 96               0.876831              -2.343283              -0.863819
# 97               2.635596               1.623670               1.353747
# 98               3.213713              -0.241490              -1.118638
# 99               4.335664               0.975387               0.749674
#
#     principal component 10  ...  principal component 12  \
# 0                 0.683973  ...                2.232560
# 1                -2.405193  ...                1.095680
# 2                 0.447583  ...               -1.317741
# 3                -1.245504  ...                2.068753
# 4                -0.044216  ...               -0.986643
# ..                     ...  ...                     ...
# 95                0.223134  ...               -0.213869
# 96               -1.865708  ...               -3.081780
# 97               -0.432171  ...                3.188518
# 98               -1.058275  ...                2.977800
# 99                2.906104  ...                2.054338
#
#     principal component 13  principal component 14  principal component 15  \
# 0                 0.284649               -0.654383                0.412075
# 1                 0.468465                2.419563                0.503833
# 2                 1.705656               -0.271960                0.458442
# 3                -2.346114                2.816273               -1.132660
# 4                -0.573329               -1.840725               -0.270546
# ..                     ...                     ...                     ...
# 95               -1.111582               -1.771401               -0.352426
# 96                0.268201                0.905105                1.159131
# 97                0.305717               -3.359833               -2.347904
# 98               -0.282330                0.323632                0.663888
# 99                4.948661               -2.057066               -3.171402
#
#     principal component 16  principal component 17  principal component 18  \
# 0                -0.640991                0.352945                0.479144
# 1                -1.361836                0.590741               -0.650669
# 2                -0.765012               -0.002881               -0.523914
# 3                -1.283340                1.144368                0.614260
# 4                -0.088507               -0.688705               -0.234532
# ..                     ...                     ...                     ...
# 95                0.103597               -0.145342               -1.120715
# 96               -0.330951               -0.648781                0.920888
# 97               -1.349490               -1.681042               -0.438927
# 98                2.433202               -3.108760               -3.334385
# 99                0.576349               -0.093963               -0.099881
#
#     principal component 19  principal component 20  HSD010_binary
# 0                -0.502138                2.294842           good
# 1                -1.490594                1.899403           good
# 2                 0.375148                3.291438           good
# 3                 0.107755               -1.096708           good
# 4                 2.173843                3.039866           good
# ..                     ...                     ...            ...
# 95                1.729696               -2.342444           good
# 96                0.059614               -2.789206           good
# 97               -1.086747                3.870769           good
# 98               -0.520445                1.755003           good
# 99                0.791947                1.966394           good
#
# [100 rows x 21 columns]

# %%
#I'll do the scatter plot of the first two componets 



# figure settings
plt.figure()
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1',fontsize=20)
plt.ylabel('Principal Component - 2',fontsize=20)
plt.title("Principal Component Analysis of Health",fontsize=20)
targets = ['good', 'poor']
colors = ['r', 'g']

# loop over targets and colors to create scatterplot
for target, color in zip(targets,colors):
    indicesToKeep = pca_df['HSD010_binary'] == target
    plt.scatter(pca_df.loc[indicesToKeep, 'principal component 1']
               , pca_df.loc[indicesToKeep, 'principal component 2'], c = color, s = 50)

# show figure
plt.legend(targets,prop={'size': 15})
plt.show();

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %% [markdown]
# I will use DBSCAN as I don't know exactly how the clusters might be allocated as I have a high dimenstionality dataset.
#
# DBSCAN identifies areas of high density separated by areas of low density. This allows it to identify clusters of any shape. It relies on the concept of core sample, that are samples in areas of high density. The cluster in this algorithm is a set of core samples each close to each other, and a set of non-core samples that are close toa core sample, but are not themselves core samples.

# %% [markdown]
# ### Cluster nhanes

# %%
#nhanes_scaled = nhanes_scaled.drop([ 'HSD010_binary'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/h0/y99pnxk16js0gj2tnr5d18d00000gn/T/ipykernel_61793/1938882084.py in <module>
# ----> 1 nhanes_scaled = nhanes_scaled.drop([ 'HSD010_binary'], axis = 1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['HSD010_binary'] not found in axis"

# %%
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ033    OHQ770    OHQ845  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -0.646584
# 73576 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -1.539259
# 73579 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -1.539259
# 73581 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -0.646584
# 73584 -0.057306  0.128246  0.080373  ... -0.680203 -2.605509  0.246091
#
#         PAAQUEX    SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x
# SEQN
# 73568 -0.484200  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440
# 73576 -0.484200  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812
# 73579  2.065262 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812
# 73581 -0.484200  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440
# 73584  2.065262  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812
#
# [5 rows x 241 columns]

# %%
#I will use the Elbow method to find the number of clusters for a KMeans 
distortions = []
K = range (1,10)
for k in K: 
    kmeanModel = KMeans (n_clusters=k)
    kmeanModel.fit(nhanes_scaled)
    distortions.append (kmeanModel.inertia_)

# %%
#Plot the distortions of K-means
plt.figure(figsize=(20,10))
plt.plot(K, distortions, 'bx-', c='r') 
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Elbow Method')
plt.show()
# Out:
# /var/folders/h0/y99pnxk16js0gj2tnr5d18d00000gn/T/ipykernel_61793/481288098.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bx-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(K, distortions, 'bx-', c='r')

# %% [markdown]
# It seems like the elbow method point towards including 6 or 7 clusters, after 7 there is not much benefit. I'll start with 7 clusters.

# %%
# Obtaining a K- means cluster of 7 clusters
kmeans = KMeans(n_clusters=7,
                 n_init=10,
               max_iter=1000 
               ).fit(nhanes_scaled)

# %%
# print the centers 
print("Centers")
print(kmeans.cluster_centers_)
print()

# print labels
print("Labels")
print(kmeans.labels_)
print()

# print coordinates and labels 
for point, label in zip(nhanes_scaled, kmeans.labels_):
    print("Coordinates:", point, "Label:", label)
# Out:
# Centers
# [[ 0.          0.01639112  0.         ...  0.00865078 -0.01093886
#   -0.98762443]
#  [ 0.         -0.01314806  0.         ...  0.12005455  0.43608539
#    0.58280013]
#  [ 0.         -0.03107081  0.         ... -0.05218653  0.00265105
#   -0.24008018]
#  ...
#  [ 0.         -0.108333    0.         ...  0.2997606   0.30746614
#    0.61244043]
#  [ 0.          0.05187998  0.         ... -0.11217881 -0.23080178
#    0.09611063]
#  [ 0.         -0.027299    0.         ... -0.01999709 -0.12915185
#    0.26467037]]
#
# Labels
# [6 0 0 ... 2 6 5]
#
# Coordinates: DR1DRSTZ Label: 6
# Coordinates: DR1EXMER Label: 0
# Coordinates: DRABF Label: 0
# Coordinates: DRDINT Label: 6
# Coordinates: DR1DBIH Label: 0
# Coordinates: DR1DAY Label: 6
# Coordinates: DR1LANG Label: 0
# Coordinates: DR1MNRSP Label: 1
# Coordinates: DR1HELPD Label: 5
# Coordinates: DBQ095Z Label: 6
# Coordinates: DRQSPREP Label: 1
# Coordinates: DR1STY Label: 1
# Coordinates: DRQSDIET Label: 6
# Coordinates: DR1TNUMF Label: 0
# Coordinates: DR1TKCAL Label: 5
# Coordinates: DR1TPROT Label: 4
# Coordinates: DR1TCARB Label: 4
# Coordinates: DR1TSUGR Label: 5
# Coordinates: DR1TFIBE Label: 3
# Coordinates: DR1TTFAT Label: 6
# Coordinates: DR1TSFAT Label: 5
# Coordinates: DR1TMFAT Label: 0
# Coordinates: DR1TPFAT Label: 6
# Coordinates: DR1TCHOL Label: 0
# Coordinates: DR1TATOC Label: 5
# Coordinates: DR1TRET Label: 0
# Coordinates: DR1TVARA Label: 5
# Coordinates: DR1TBCAR Label: 3
# Coordinates: DR1TLZ Label: 6
# Coordinates: DR1TVB1 Label: 1
# Coordinates: DR1TVB2 Label: 4
# Coordinates: DR1TNIAC Label: 6
# Coordinates: DR1TVB6 Label: 6
# Coordinates: DR1TFOLA Label: 1
# Coordinates: DR1TFA Label: 1
# Coordinates: DR1TFF Label: 6
# Coordinates: DR1TFDFE Label: 1
# Coordinates: DR1TCHL Label: 5
# Coordinates: DR1TVB12 Label: 1
# Coordinates: DR1TVC Label: 0
# Coordinates: DR1TVD Label: 1
# Coordinates: DR1TVK Label: 1
# Coordinates: DR1TCALC Label: 6
# Coordinates: DR1TPHOS Label: 2
# Coordinates: DR1TMAGN Label: 0
# Coordinates: DR1TIRON Label: 6
# Coordinates: DR1TZINC Label: 5
# Coordinates: DR1TCOPP Label: 2
# Coordinates: DR1TSODI Label: 6
# Coordinates: DR1TPOTA Label: 5
# Coordinates: DR1TSELE Label: 0
# Coordinates: DR1TMOIS Label: 0
# Coordinates: DR1TS040 Label: 6
# Coordinates: DR1TS060 Label: 4
# Coordinates: DR1TS080 Label: 5
# Coordinates: DR1TS100 Label: 1
# Coordinates: DR1TS120 Label: 5
# Coordinates: DR1TS140 Label: 2
# Coordinates: DR1TS160 Label: 0
# Coordinates: DR1TS180 Label: 4
# Coordinates: DR1TM161 Label: 5
# Coordinates: DR1TM181 Label: 6
# Coordinates: DR1TM201 Label: 6
# Coordinates: DR1TP182 Label: 1
# Coordinates: DR1TP183 Label: 2
# Coordinates: DR1TP204 Label: 0
# Coordinates: DR1.300 Label: 6
# Coordinates: DR1TWS Label: 6
# Coordinates: DRD340 Label: 1
# Coordinates: DRD360 Label: 6
# Coordinates: PEASCST1 Label: 1
# Coordinates: PEASCTM1 Label: 3
# Coordinates: BPXPULS Label: 2
# Coordinates: BMDSTATS Label: 1
# Coordinates: BMXWT Label: 5
# Coordinates: BMXHT Label: 6
# Coordinates: BMXBMI Label: 0
# Coordinates: BMXARML Label: 5
# Coordinates: BMXARMC Label: 2
# Coordinates: BMXWAIST Label: 5
# Coordinates: MGDEXSTS Label: 3
# Coordinates: OHDEXSTS Label: 0
# Coordinates: OHDDESTS Label: 0
# Coordinates: OHX01TC Label: 2
# Coordinates: OHX02TC Label: 0
# Coordinates: OHX03TC Label: 5
# Coordinates: OHX04TC Label: 1
# Coordinates: OHX05TC Label: 5
# Coordinates: OHX06TC Label: 0
# Coordinates: OHX07TC Label: 6
# Coordinates: OHX08TC Label: 0
# Coordinates: OHX09TC Label: 6
# Coordinates: OHX10TC Label: 5
# Coordinates: OHX11TC Label: 3
# Coordinates: OHX12TC Label: 5
# Coordinates: OHX13TC Label: 2
# Coordinates: OHX14TC Label: 1
# Coordinates: OHX15TC Label: 0
# Coordinates: OHX16TC Label: 4
# Coordinates: OHX17TC Label: 6
# Coordinates: OHX18TC Label: 5
# Coordinates: OHX19TC Label: 5
# Coordinates: OHX20TC Label: 4
# Coordinates: OHX21TC Label: 6
# Coordinates: OHX22TC Label: 6
# Coordinates: OHX23TC Label: 5
# Coordinates: OHX24TC Label: 5
# Coordinates: OHX25TC Label: 0
# Coordinates: OHX26TC Label: 0
# Coordinates: OHX27TC Label: 0
# Coordinates: OHX28TC Label: 1
# Coordinates: OHX29TC Label: 3
# Coordinates: OHX30TC Label: 0
# Coordinates: OHX31TC Label: 1
# Coordinates: OHX32TC Label: 2
# Coordinates: URXUMA Label: 6
# Coordinates: URXUMS Label: 1
# Coordinates: URXUCR.x Label: 0
# Coordinates: URXCRS Label: 6
# Coordinates: URDACT Label: 1
# Coordinates: LBXWBCSI Label: 0
# Coordinates: LBXLYPCT Label: 2
# Coordinates: LBXMOPCT Label: 5
# Coordinates: LBXNEPCT Label: 5
# Coordinates: LBXEOPCT Label: 3
# Coordinates: LBXBAPCT Label: 5
# Coordinates: LBDLYMNO Label: 5
# Coordinates: LBDMONO Label: 5
# Coordinates: LBDNENO Label: 5
# Coordinates: LBXRBCSI Label: 5
# Coordinates: LBXHGB Label: 6
# Coordinates: LBXHCT Label: 1
# Coordinates: LBXMCVSI Label: 0
# Coordinates: LBXMCHSI Label: 1
# Coordinates: LBXMC Label: 1
# Coordinates: LBXRDW Label: 0
# Coordinates: LBXPLTSI Label: 3
# Coordinates: LBXMPSI Label: 3
# Coordinates: PHQ020 Label: 5
# Coordinates: PHQ030 Label: 5
# Coordinates: PHQ040 Label: 6
# Coordinates: PHQ050 Label: 6
# Coordinates: PHQ060 Label: 6
# Coordinates: PHAFSTMN.x Label: 5
# Coordinates: LBXHA Label: 0
# Coordinates: LBXHBS Label: 6
# Coordinates: URXVOL1 Label: 5
# Coordinates: SDDSRVYR Label: 2
# Coordinates: RIDSTATR Label: 1
# Coordinates: RIAGENDR Label: 6
# Coordinates: RIDAGEYR Label: 5
# Coordinates: RIDRETH1 Label: 5
# Coordinates: RIDRETH3 Label: 1
# Coordinates: RIDEXMON Label: 5
# Coordinates: DMDBORN4 Label: 0
# Coordinates: DMDCITZN Label: 2
# Coordinates: SIALANG Label: 6
# Coordinates: SIAPROXY Label: 1
# Coordinates: SIAINTRP Label: 1
# Coordinates: FIALANG Label: 5
# Coordinates: FIAPROXY Label: 6
# Coordinates: FIAINTRP Label: 2
# Coordinates: DMDHHSIZ Label: 5
# Coordinates: DMDFMSIZ Label: 2
# Coordinates: DMDHRGND Label: 0
# Coordinates: DMDHRAGE Label: 4
# Coordinates: DMDHRBR4 Label: 5
# Coordinates: DMDHREDU Label: 1
# Coordinates: DMDHRMAR Label: 6
# Coordinates: WTINT2YR Label: 5
# Coordinates: WTMEC2YR Label: 6
# Coordinates: SDMVPSU Label: 5
# Coordinates: SDMVSTRA Label: 5
# Coordinates: INDHHIN2 Label: 6
# Coordinates: INDFMIN2 Label: 5
# Coordinates: INDFMPIR Label: 0
# Coordinates: CBD070 Label: 1
# Coordinates: HSQ500 Label: 6
# Coordinates: HSQ510 Label: 2
# Coordinates: HSQ520 Label: 2
# Coordinates: HSAQUEX Label: 1
# Coordinates: DIQ010 Label: 1
# Coordinates: DIQ050 Label: 0
# Coordinates: DLQ010 Label: 6
# Coordinates: DLQ020 Label: 0
# Coordinates: DLQ040 Label: 6
# Coordinates: DLQ050 Label: 2
# Coordinates: DLQ060 Label: 5
# Coordinates: FSD032A Label: 0
# Coordinates: FSD032B Label: 1
# Coordinates: FSD032C Label: 0
# Coordinates: FSDHH Label: 2
# Coordinates: FSDAD Label: 1
# Coordinates: FSD151 Label: 4
# Coordinates: FSQ165 Label: 5
# Coordinates: FSQ162 Label: 0
# Coordinates: HEQ010 Label: 4
# Coordinates: HEQ030 Label: 0
# Coordinates: HIQ011 Label: 0
# Coordinates: HIQ270 Label: 2
# Coordinates: HIQ210 Label: 1
# Coordinates: HOD050 Label: 5
# Coordinates: HOQ065 Label: 6
# Coordinates: HUQ010 Label: 5
# Coordinates: HUQ020 Label: 5
# Coordinates: HUQ030 Label: 3
# Coordinates: HUQ041 Label: 2
# Coordinates: HUQ071 Label: 5
# Coordinates: HUQ090 Label: 2
# Coordinates: IMQ011 Label: 0
# Coordinates: IMQ020 Label: 1
# Coordinates: INQ020 Label: 0
# Coordinates: INQ012 Label: 5
# Coordinates: INQ030 Label: 2
# Coordinates: INQ060 Label: 1
# Coordinates: INQ080 Label: 5
# Coordinates: INQ090 Label: 6
# Coordinates: INQ132 Label: 6
# Coordinates: INQ140 Label: 1
# Coordinates: INQ150 Label: 1
# Coordinates: IND235 Label: 1
# Coordinates: INDFMMPI Label: 0
# Coordinates: INDFMMPC Label: 2
# Coordinates: MCQ010 Label: 1
# Coordinates: MCQ053 Label: 5
# Coordinates: MCQ082 Label: 1
# Coordinates: MCQ086 Label: 2
# Coordinates: MCQ092 Label: 6
# Coordinates: MCQ203 Label: 6
# Coordinates: MCQ300B Label: 1
# Coordinates: OHQ030 Label: 6
# Coordinates: OHQ033 Label: 1
# Coordinates: OHQ770 Label: 2
# Coordinates: OHQ845 Label: 1
# Coordinates: PAAQUEX Label: 0
# Coordinates: SMQ860 Label: 0
# Coordinates: SMQ870 Label: 5
# Coordinates: SMQ872 Label: 1
# Coordinates: SMQ874 Label: 6
# Coordinates: SMQ878 Label: 2
# Coordinates: SMAQUEX.x Label: 5

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
nhanes_scaled['cluster']=kmeans.labels_

# %%
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  cluster
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440        6
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812        0
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812        0
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440        6
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812        0
#
# [5 rows x 242 columns]

# %%
BMI_Income = ['INDFMPIR', 'BMXBMI', 'cluster']  
bmi_inc_df = nhanes_scaled[BMI_Income]

# %%
#Plot the clusters over BMI and Income Poverty Radio 
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue="cluster", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
       ylabel = "Body Mass Index")
ax.set_title("Cluster Analysis with K-Means and 7 clusters")
plt.show()

# %%
# That was not clear at all, lets see how it looks with 3 clusters. Obtaining a K- means cluster of 3 clusters
kmeans = KMeans(n_clusters=3,
                 n_init=10,
               max_iter=1000 
               ).fit(nhanes_scaled)

# %%
nhanes_scaled['cluster3']=kmeans.labels_

# %%
#Plot the clusters over BMI and Income Poverty Radio 
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue="cluster3", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
       ylabel = "Body Mass Index")
ax.set_title("Cluster Analysis with K-Means and 3 clusters")
plt.show()

# %%
#Lets make 20 clusters and see 
kmeans = KMeans(n_clusters=20,
                 n_init=10,
               max_iter=1000 
               ).fit(nhanes_scaled)

nhanes_scaled['cluster20']=kmeans.labels_
#Plot the clusters over BMI and Income Poverty Radio 
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue="cluster20", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
       ylabel = "Body Mass Index")
ax.set_title("Cluster Analysis with K-Means and 3 clusters")
plt.show()

# %%
#I will keep the 7 cluster for now.  The problem might be just in these two dimensions.

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
pca_df.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               9.527811              -0.816224              -1.867090
# 1              -5.838339              -3.692573               3.805751
# 2              -0.719454              -2.573200               0.907903
# 3               3.533627              -2.576982              -3.249123
# 4              -6.872094              -4.194241               0.886832
#
#    principal component 4  principal component 5  principal component 6  \
# 0              -2.109892              -3.929294              -0.185683
# 1              -1.029616               0.394502               1.591797
# 2              -4.755835              -1.798878               0.863717
# 3              -0.405349               3.999210               1.443931
# 4              -0.848957              -0.524810               0.072990
#
#    principal component 7  principal component 8  principal component 9  \
# 0              -3.844800              -2.934948               1.515702
# 1               2.712994              -0.739719               0.385884
# 2              -1.024231               0.632360               0.540469
# 3              -1.181528               0.328007              -4.145221
# 4               0.844501               0.985883               0.556338
#
#    principal component 10  ...  principal component 12  \
# 0                0.683973  ...                2.232560
# 1               -2.405193  ...                1.095680
# 2                0.447583  ...               -1.317741
# 3               -1.245504  ...                2.068753
# 4               -0.044216  ...               -0.986643
#
#    principal component 13  principal component 14  principal component 15  \
# 0                0.284649               -0.654383                0.412075
# 1                0.468465                2.419563                0.503833
# 2                1.705656               -0.271960                0.458442
# 3               -2.346114                2.816273               -1.132660
# 4               -0.573329               -1.840725               -0.270546
#
#    principal component 16  principal component 17  principal component 18  \
# 0               -0.640991                0.352945                0.479144
# 1               -1.361836                0.590741               -0.650669
# 2               -0.765012               -0.002881               -0.523914
# 3               -1.283340                1.144368                0.614260
# 4               -0.088507               -0.688705               -0.234532
#
#    principal component 19  principal component 20  HSD010_binary
# 0               -0.502138                2.294842           good
# 1               -1.490594                1.899403           good
# 2                0.375148                3.291438           good
# 3                0.107755               -1.096708           good
# 4                2.173843                3.039866           good
#
# [5 rows x 21 columns]

# %%
pca_df = pca_df.drop(['HSD010_binary'], axis = 1)

cluster_pca = KMeans(n_clusters=7,
               max_iter=10000).fit(pca_df)

# %%
pca_df['cluster_pca']=cluster_pca.labels_
pca_df['cluster_pca']
# Out:
# 0       3
# 1       5
# 2       5
# 3       3
# 4       5
#        ..
# 2059    3
# 2060    2
# 2061    2
# 2062    3
# 2063    0
# Name: cluster_pca, Length: 2064, dtype: int32

# %%
#Plot four clusters on the first two principal components
ax = sns.scatterplot(x = "principal component 1", y = "principal component 2", hue="cluster_pca", palette = "tab10", data = pca_df)
ax.set(xlabel = "Principal Component 1",
       ylabel = "Principal Component 2")
ax.set_title("2 PCA components vs 7 K-means clusters")
plt.show()

# %% [markdown]
# The result is clear on how  PCAs components and clusters are capturing similar associations. I had 20 PCAs and 7 clusters, so in both cases I diminished the size of the features in an important scale and it seems I am capturing similar information with both. I like that clustering helps to identify elements that are in between the PCA components, for example the green cluster (2) and brown (5) capture groups that might be hard to separate otherwise. Clearly there are other components that are playing a role on the clustering as clusters are not overlapping exactly each component.

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
# partition data
# -----------
y = ... # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X = ... # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = ...
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(..., ...)
y_test = keras.utils.to_categorical(..., ...)
num_classes = y_test.shape[1]

# %%
# create neural network model
# -----------
model = Sequential()

model.add(Dense(..., input_dim= ..., kernel_initializer= ..., activation= ...))

model.add(Dense(..., kernel_initializer= ..., activation= ...))

## Add any additional layers you wish here

model.compile(loss= ..., optimizer= ..., metrics=[...])

model.fit(..., ..., validation_data=(..., ...), epochs=..., batch_size=..., verbose=...)

# %% [markdown]
# ### Neural Network on Principal Components

# %%
## Your Answer Here

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
## Your Answer Here

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"
